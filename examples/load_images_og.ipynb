# %%
import os
from seasight.loaders.roboflow import RoboflowDatasetLoader

# %% [markdown]
# ## Load Sea Vessels Dataset
#
# - https://universe.roboflow.com/yehonatan-engel/sea-vessels-dataset/dataset/2
#
# - The following cell will download the images in `TFRecord` format and store them in the `data` directory at the root of the repo.

# %%
api_key = os.getenv("ROBOFLOW_API_KEY")
workspace = "shipclassification"
project_name = "shipclassification"
version_number = 4

downloader = RoboflowDatasetLoader(api_key, workspace, project_name, version_number)
downloader.download_dataset()
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in ShipClassification-4 to tfrecord:: 100%|██████████| 84220/84220 [00:10<00:00, 7790.39it/s]
# Extracting Dataset Version Zip to ShipClassification-4 in tfrecord:: 100%|██████████| 11/11 [00:00<00:00, 66.33it/s]
# Dataset moved to ../data/

# %% [markdown]
# ## EDA

# %%
from seasight.eda.plots import TFRecordPlots
# Out:
# 2024-03-14 19:19:38.185396: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-03-14 19:19:38.917914: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# - Random training image

# %%
file_path = '../data/ShipClassification-4/train/Ships.tfrecord'
TFRecordPlots.display_random_image_from_tfrecord(file_path)
# Out:
# 2024-03-14 19:20:57.159354: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %% [markdown]
# - Random test image

# %%
file_path = '../data/ShipClassification-4/test/Ships.tfrecord'
TFRecordPlots.display_random_image_from_tfrecord(file_path)
# Out:
# 2024-03-14 19:21:00.999099: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %% [markdown]
# - Random validation image

# %%
file_path = '../data/ShipClassification-4/valid/Ships.tfrecord'
TFRecordPlots.display_random_image_from_tfrecord(file_path)
# Out:
# 2024-03-14 19:21:03.573367: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
